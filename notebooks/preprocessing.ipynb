# %%
import pandas as pd

# %%
df_brand = pd.read_csv('/content/brand_category.csv')

# %%
df_cat = pd.read_csv('/content/categories.csv')

# %%
df_offer = pd.read_csv('/content/offer_retailer.csv')

# %%
df_brand.head()
# Out:
#               BRAND BRAND_BELONGS_TO_CATEGORY  RECEIPTS
# 0  CASEYS GEN STORE          Tobacco Products   2950931
# 1  CASEYS GEN STORE                    Mature   2859240
# 2            EQUATE              Hair Removal    893268
# 3         PALMOLIVE               Bath & Body    542562
# 4              DAWN               Bath & Body    301844

# %%
df_brand.rename({'BRAND_BELONGS_TO_CATEGORY':'PRODUCT_CATEGORY'},axis=1, inplace=True)

# %%
df_brand.head()
# Out:
#               BRAND  PRODUCT_CATEGORY  RECEIPTS
# 0  CASEYS GEN STORE  Tobacco Products   2950931
# 1  CASEYS GEN STORE            Mature   2859240
# 2            EQUATE      Hair Removal    893268
# 3         PALMOLIVE       Bath & Body    542562
# 4              DAWN       Bath & Body    301844

# %%
df_brand.drop('RECEIPTS', axis=1, inplace=True)
df_brand.head()
# Out:
#               BRAND  PRODUCT_CATEGORY
# 0  CASEYS GEN STORE  Tobacco Products
# 1  CASEYS GEN STORE            Mature
# 2            EQUATE      Hair Removal
# 3         PALMOLIVE       Bath & Body
# 4              DAWN       Bath & Body

# %%
df_cat.head()
# Out:
#                             CATEGORY_ID             PRODUCT_CATEGORY  \
# 0  1f7d2fa7-a1d7-4969-aaf4-1244f232c175              Red Pasta Sauce
# 1  3e48a9b3-1ab2-4f2d-867d-4a30828afeab  Alfredo & White Pasta Sauce
# 2  09f3decc-aa93-460d-936c-0ddf06b055a3             Cooking & Baking
# 3  12a89b18-4c01-4048-94b2-0705e0a45f6b             Packaged Seafood
# 4  2caa015a-ca32-4456-a086-621446238783             Feminine Hygeine
#
#   IS_CHILD_CATEGORY_TO
# 0          Pasta Sauce
# 1          Pasta Sauce
# 2               Pantry
# 3               Pantry
# 4    Health & Wellness

# %%
df_cat.drop(['CATEGORY_ID','IS_CHILD_CATEGORY_TO'],axis=1,inplace=True)
df_cat.head()
# Out:
#               PRODUCT_CATEGORY
# 0              Red Pasta Sauce
# 1  Alfredo & White Pasta Sauce
# 2             Cooking & Baking
# 3             Packaged Seafood
# 4             Feminine Hygeine

# %%
df_merge = pd.concat([df_brand, df_cat])
df_merge.head()
# Out:
#               BRAND  PRODUCT_CATEGORY
# 0  CASEYS GEN STORE  Tobacco Products
# 1  CASEYS GEN STORE            Mature
# 2            EQUATE      Hair Removal
# 3         PALMOLIVE       Bath & Body
# 4              DAWN       Bath & Body

# %%
df_merge.shape
# Out:
# (10024, 2)

# %%
df_brand.shape
# Out:
# (9906, 2)

# %%
df_merge.isnull().sum()
# Out:
# BRAND               119
# PRODUCT_CATEGORY      0
# dtype: int64

# %%
df_offer.head()
# Out:
#                                                OFFER            RETAILER  \
# 0     Spend $50 on a Full-Priced new Club Membership           SAMS CLUB
# 1       Beyond Meat® Plant-Based products, spend $25                 NaN
# 2           Good Humor Viennetta Frozen Vanilla Cake                 NaN
# 3  Butterball, select varieties, spend $10 at Dil...  DILLONS FOOD STORE
# 4  GATORADE® Fast Twitch®, 12-ounce 12 pack, at A...              AMAZON
#
#          BRAND
# 0    SAMS CLUB
# 1  BEYOND MEAT
# 2   GOOD HUMOR
# 3   BUTTERBALL
# 4     GATORADE

# %%
df_merge_final = pd.merge(df_merge, df_offer, on='BRAND')

# %%
df_merge_final.head()
# Out:
#           BRAND        PRODUCT_CATEGORY  \
# 0     DR PEPPER  Carbonated Soft Drinks
# 1     DR PEPPER        Cooking & Baking
# 2  MOUNTAIN DEW  Carbonated Soft Drinks
# 3         PEPSI  Carbonated Soft Drinks
# 4         PEPSI  Carbonated Soft Drinks
#
#                                                OFFER             RETAILER
# 0  Dr Pepper®, Regular OR Zero Sugar Strawberries...  UNITED SUPERMARKETS
# 1  Dr Pepper®, Regular OR Zero Sugar Strawberries...  UNITED SUPERMARKETS
# 2  MTN DEW® Kickstart, 16-ounce 12 count, select ...               AMAZON
# 3  PepsiCo® Beverage, 7.5-ounce 10 pack, select v...               AMAZON
# 4  PepsiCo® Variety Pack, select varieties, at Am...               AMAZON

# %%
df_merge_final.isnull().sum()
# Out:
# BRAND                 0
# PRODUCT_CATEGORY      0
# OFFER                 0
# RETAILER            423
# dtype: int64

# %%
df_merge_final.shape
# Out:
# (776, 4)

# %%
df_offer.shape
# Out:
# (384, 3)

# %%
df_merge_final['RETAILER'] = df_merge_final['RETAILER'].fillna('NA')

# %%
df_merge_final.head()
# Out:
#           BRAND        PRODUCT_CATEGORY  \
# 0     DR PEPPER  Carbonated Soft Drinks
# 1     DR PEPPER        Cooking & Baking
# 2  MOUNTAIN DEW  Carbonated Soft Drinks
# 3         PEPSI  Carbonated Soft Drinks
# 4         PEPSI  Carbonated Soft Drinks
#
#                                                OFFER             RETAILER
# 0  Dr Pepper®, Regular OR Zero Sugar Strawberries...  UNITED SUPERMARKETS
# 1  Dr Pepper®, Regular OR Zero Sugar Strawberries...  UNITED SUPERMARKETS
# 2  MTN DEW® Kickstart, 16-ounce 12 count, select ...               AMAZON
# 3  PepsiCo® Beverage, 7.5-ounce 10 pack, select v...               AMAZON
# 4  PepsiCo® Variety Pack, select varieties, at Am...               AMAZON

# %%
df_merge_final.isnull().sum()
# Out:
# BRAND               0
# PRODUCT_CATEGORY    0
# OFFER               0
# RETAILER            0
# dtype: int64

# %%
df_merge_final.shape
# Out:
# (776, 4)

# %%
df_merge_final.to_csv('final.csv')
